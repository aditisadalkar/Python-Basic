# %% [markdown]
# # Advance Data Type
# # 1)List
# # 2)Tuple
# # 3)Set
# # 4)Dictionary

# %% [markdown]
# # 1-List Example

# %%
#1-List Example
sub= ["Math","Science","English"]
sub.append("Python")
print(sub)
print(sub[2])
# Out:
# ['Math', 'Science', 'English', 'Python']
# English

# %% [markdown]
# # 2-Tuple Example

# %%
#2-Tuple Example
days=("Monday","Tuesday","Wednesday")
print(days)
print(days[0])
# Out:
# ('Monday', 'Tuesday', 'Wednesday')
# Monday

# %% [markdown]
# # Set Example

# %%
#Set Example
city={"Pune","Mumbai","Nagpur"}
city.add("Nashik")
print(city)
# Out:
# {'Nagpur', 'Mumbai', 'Pune', 'Nashik'}

# %% [markdown]
# # Dictionary Example

# %%
#Dictionary Example
book={"title":"Python Programming",
      "author":"XYZ",
      "price":500}
print(book["title"])
# Out:
# Python Programming
