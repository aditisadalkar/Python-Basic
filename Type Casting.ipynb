# %%
Name:Aditi Vishwanath Sadalkar
Roll number:2110

# %%
Day 1
3-June-2026
Task 1: Type Casting

# %%
1) int -> float,str,bool,complex

# %%
a=3
print(type(a))
# Out:
# <class 'int'>

# %%
a1=float(a)
print((a1))
# Out:
# 3.0

# %%
a2=str(a)
print(a2,type(a2))
# Out:
# 3 <class 'str'>

# %%
a3=bool(a)
print(a3,type(a3))
# Out:
# True <class 'bool'>

# %%
a4=complex(a)
print(a4)
# Out:
# (3+0j)

# %%
2)float-> int,str,bool,complex

# %%
b=3.5
print(b,type(b))
# Out:
# 3.5 <class 'float'>

# %%
b1=int(b)
print(int(b1))
# Out:
# 3

# %%
b2=str(b)
print(b2,type(b2))
# Out:
# 3.5 <class 'str'>

# %%
b3=bool(b)
print(b3,type(b3))
# Out:
# True <class 'bool'>

# %%
b4=complex(b)
print(complex(b4))
# Out:
# (3.5+0j)

# %%
3)str-> float,int,bool,complex

# %%
c="3"
print(c,type(c))
# Out:
# 3 <class 'str'>

# %%
c1=float(c)
print(float(c1))
# Out:
# 3.0

# %%
c2=int(c)
print(int(c2))
# Out:
# 3

# %%
c3=bool(c)
print(c3,type(c3))
# Out:
# True <class 'bool'>

# %%
c4=complex(c)
print(complex(c4))
# Out:
# (3+0j)

# %%
4)bool-> float,str,int,complex

# %%
d=True
print(d,type(d))
# Out:
# True <class 'bool'>

# %%
d1=float(d)
print(float(d1))
# Out:
# 1.0

# %%
d2=str(d)
print(str(d2))
# Out:
# True

# %%
d3=int(d)
print(int(d3))
# Out:
# 1

# %%
d4=complex(d)
print(complex(d4))
# Out:
# (1+0j)

# %%
5)complex-> float,str,bool,int

# %%
e=2+3j
print(e)
# Out:
# (2+3j)

# %%
e1=str(e)
print(str(e1))
# Out:
# (2+3j)

# %%
int(e)              #Type Error
float(e)

# %%
e2=bool(e)
print(bool(e2))
# Out:
# True
